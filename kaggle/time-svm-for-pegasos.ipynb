# %%
import numpy as np
import pandas as pd
import re
import nltk
import string
nltk.download('stopwords')
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer, HashingVectorizer
from sklearn.model_selection import train_test_split
from bs4 import BeautifulSoup
from sklearn.metrics import confusion_matrix,accuracy_score, f1_score, precision_score,recall_score,classification_report
import time
from sklearn.svm import SVC
from google.colab import drive
import pickle
from scipy.sparse import csr_matrix
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /usr/share/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
class SVM:
    def __init__(self, lambda_param=1e-4, epoch=1000, batch_size=256, tol=1e-4, random_state=42):
        self.lambda_param = lambda_param
        self.epoch = epoch
        self.batch_size = batch_size
        self.tol = tol
        self.random_state = random_state
        self.is_trained = False

    def fit(self, X, y):
        if hasattr(X, "toarray"):
            X = csr_matrix(X)
        
        self.num_samples, self.num_features = X.shape

        y_unique = np.unique(y)
        if len(y_unique) != 2:
            raise ValueError("Phân loại nhị phân cần 2 nhãn")
        if set(y_unique) == {0, 1}:
            y = np.where(y == 0, -1, 1)
        
        self.w = np.zeros(self.num_features, dtype=np.float32)
        self.b = 0.0

        np.random.seed(self.random_state)
        t = 0
        previous_objective = float("inf")

        for ep in range(1, self.epoch + 1):
            indices = np.random.permutation(self.num_samples)
            for start in range(0, self.num_samples, self.batch_size):
                t += 1
                end = start + self.batch_size
                batch_idx = indices[start:end]
                X_batch = X[batch_idx]
                y_batch = y[batch_idx]
                
                eta = 1.0 / (self.lambda_param * t)
                margins = y_batch * (X_batch.dot(self.w) + self.b)
                mask = margins < 1
                self.w *= (1 - eta * self.lambda_param)
                if np.any(mask):
                    X_violate = X_batch[mask]
                    y_violate = y_batch[mask]
                    self.w += (eta / self.batch_size) * np.dot(y_violate, X_violate.toarray() if hasattr(X_violate, "toarray") else X_violate)
                    self.b += (eta / self.batch_size) * np.sum(y_violate)
                norm_w = np.linalg.norm(self.w)
                factor = min(1, (1.0 / np.sqrt(self.lambda_param)) / (norm_w))
                self.w *= factor

            decision = X.dot(self.w) + self.b
            hinge_losses = np.maximum(0, 1 - y * decision)
            objective = 0.5 * self.lambda_param * np.dot(self.w, self.w) + np.mean(hinge_losses)
            
            if ep % 10 == 0:
                print(f"Epoch {ep}, Giá trị hàm mục tiêu: {objective:.4f}")
            
            if abs(previous_objective - objective) < self.tol:
                print(f"Dừng sớm tại epoch {ep}, giá trị hàm mục tiêu thay đổi: {abs(previous_objective - objective):.6f}")
                break
            previous_objective = objective

        self.is_trained = True
        return self

    def predict(self, X):
        if not self.is_trained:
            raise Exception("Mô hình chưa được huấn luỵen")
            
        if hasattr(X, "toarray"):
            X = csr_matrix(X)
            
        decision = X.dot(self.w) + self.b
        return np.where(decision >= 0, 1, 0)

# %%
a = [i for i in range(1000, 10000, 500)]
def calc_time_svm():
    for i in a:
        df = pd.read_csv(f"https://media.githubusercontent.com/media/PTIT-Projects/ttcs-svm-spam-email/refs/heads/main/dataset/sampled_dataset{i}.csv")
        print("Start preprocessing data")
        prep_start_time = time.time()
        df['text'] = df['text'].str.lower()
        
        # xoa ky tu khong phai ASCII
        df['text'] = df['text'].apply(lambda x: re.sub(r'[^\x00-\x7F]+', '', x) if isinstance(x, str) else x)
    
        # xoa khoang trang
        df['text'] = df['text'].apply(lambda x: re.sub(r'^\s+|\s+$', '', x).strip() if isinstance(x, str) else x)
    
        # xoa html, xml
        def remove_html_xml(text):
            try:
                soup = BeautifulSoup(text, 'html.parser')
                return soup.get_text()
            except:
                return text
        df['text'] = df['text'].apply(remove_html_xml)
        def remove_special_characters(word):
            return word.translate(str.maketrans('', '', string.punctuation))
        df['text'] = df['text'].apply(remove_special_characters)
        def remove_urls(text):
            return re.sub(r'http\S+|www\S+|\S+\.(com|net|org|edu|gov|mil|int|info|biz|co)\S+', '', text)
        df['text'] = df['text'].apply(remove_urls)
        def remove_emails(text):
            return re.sub(r'\S+@\S+', '', text)
        df['text'] = df['text'].apply(remove_emails)
        df['text'] = df['text'].apply(word_tokenize)
        ENGLISH_STOP_WORDS = set(stopwords.words('english'))
        def remove_stop_words(words):
            return [word for word in words if word not in ENGLISH_STOP_WORDS]
        df['text'] = df['text'].apply(remove_stop_words)
        stemmer = PorterStemmer()
        def stem_words(words):
            return [stemmer.stem(word) for word in words]
        df['text'] = df['text'].apply(stem_words)
        df['text'] = df['text'].apply(' '.join)
        X = df['text']
        y = df['label']
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
        hashing_vectorizer = TfidfVectorizer()
        X_train_hashed = hashing_vectorizer.fit_transform(X_train)
        X_test_hashed = hashing_vectorizer.transform(X_test)
        print(X_train_hashed.shape)
        print("End preprocessing data")
        prep_end_time = time.time()
        svm_base = SVM()
        start_time = time.time()
        svm_base.fit(X_train_hashed, y_train)
        end_time = time.time()
        y_pred = svm_base.predict(X_test_hashed)
        accuracy = accuracy_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        result = {
        'class_name': svm_base.__class__.__name__,
        'n': len(df),
        'time': end_time - start_time,
        'prep_time': prep_end_time - prep_start_time ,
        'accuracy_score': accuracy,
        'f1_score': f1
        }
        results_df = pd.DataFrame([result])
        print(results_df)
        results_df.to_csv(f'svm_pegasos_{i}.csv', index=False)

# %%
calc_time_svm()
# Out:
# Start preprocessing data
# (800, 15517)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 32.6296
# Epoch 20, Giá trị hàm mục tiêu: 1.1482
# Epoch 30, Giá trị hàm mục tiêu: 1.6400
# Epoch 40, Giá trị hàm mục tiêu: 1.4125
# Epoch 50, Giá trị hàm mục tiêu: 0.4692
# Epoch 60, Giá trị hàm mục tiêu: 0.3155
# Epoch 70, Giá trị hàm mục tiêu: 0.2233
# Epoch 80, Giá trị hàm mục tiêu: 0.2225
# Epoch 90, Giá trị hàm mục tiêu: 0.1400
# Epoch 100, Giá trị hàm mục tiêu: 0.6319
# Epoch 110, Giá trị hàm mục tiêu: 0.1472
# Epoch 120, Giá trị hàm mục tiêu: 0.1190
# Epoch 130, Giá trị hàm mục tiêu: 0.1022
# Epoch 140, Giá trị hàm mục tiêu: 0.0883
# Epoch 150, Giá trị hàm mục tiêu: 0.0779
# Epoch 160, Giá trị hàm mục tiêu: 0.1303
# Epoch 170, Giá trị hàm mục tiêu: 0.0809
# Epoch 180, Giá trị hàm mục tiêu: 0.0704
# Epoch 190, Giá trị hàm mục tiêu: 0.1427
# Epoch 200, Giá trị hàm mục tiêu: 0.0667
# Epoch 210, Giá trị hàm mục tiêu: 0.0611
# Epoch 220, Giá trị hàm mục tiêu: 0.0556
# Epoch 230, Giá trị hàm mục tiêu: 0.5965
# Epoch 240, Giá trị hàm mục tiêu: 0.0570
# Epoch 250, Giá trị hàm mục tiêu: 0.0526
# Epoch 260, Giá trị hàm mục tiêu: 0.0491
# Dừng sớm tại epoch 262, giá trị hàm mục tiêu thay đổi: 0.000012
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  1000  1.119965   3.942703            0.93  0.932692
# Start preprocessing data
# (1200, 20072)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 3.1212
# Epoch 20, Giá trị hàm mục tiêu: 4.0304
# Epoch 30, Giá trị hàm mục tiêu: 0.7660
# Epoch 40, Giá trị hàm mục tiêu: 0.3823
# Epoch 50, Giá trị hàm mục tiêu: 0.3820
# Epoch 60, Giá trị hàm mục tiêu: 0.2431
# Epoch 70, Giá trị hàm mục tiêu: 0.1802
# Epoch 80, Giá trị hàm mục tiêu: 0.1918
# Epoch 90, Giá trị hàm mục tiêu: 0.1192
# Epoch 100, Giá trị hàm mục tiêu: 0.1322
# Epoch 110, Giá trị hàm mục tiêu: 0.1086
# Epoch 120, Giá trị hàm mục tiêu: 0.1046
# Epoch 130, Giá trị hàm mục tiêu: 0.3456
# Epoch 140, Giá trị hàm mục tiêu: 0.1052
# Epoch 150, Giá trị hàm mục tiêu: 0.0799
# Epoch 160, Giá trị hàm mục tiêu: 0.1488
# Epoch 170, Giá trị hàm mục tiêu: 0.0706
# Epoch 180, Giá trị hàm mục tiêu: 0.0741
# Epoch 190, Giá trị hàm mục tiêu: 0.0639
# Epoch 200, Giá trị hàm mục tiêu: 0.0628
# Epoch 210, Giá trị hàm mục tiêu: 0.0576
# Dừng sớm tại epoch 217, giá trị hàm mục tiêu thay đổi: 0.000095
#   class_name     n     time  prep_time  accuracy_score  f1_score
# 0        SVM  1500  1.48222   5.948407        0.963333  0.966967
# Start preprocessing data
# (1600, 24391)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 16.5451
# Epoch 20, Giá trị hàm mục tiêu: 5.1187
# Epoch 30, Giá trị hàm mục tiêu: 0.7592
# Epoch 40, Giá trị hàm mục tiêu: 0.5137
# Epoch 50, Giá trị hàm mục tiêu: 0.2370
# Epoch 60, Giá trị hàm mục tiêu: 0.1998
# Epoch 70, Giá trị hàm mục tiêu: 0.1642
# Epoch 80, Giá trị hàm mục tiêu: 0.1292
# Epoch 90, Giá trị hàm mục tiêu: 0.1045
# Epoch 100, Giá trị hàm mục tiêu: 0.1041
# Epoch 110, Giá trị hàm mục tiêu: 0.1343
# Epoch 120, Giá trị hàm mục tiêu: 0.0776
# Epoch 130, Giá trị hàm mục tiêu: 0.0799
# Epoch 140, Giá trị hàm mục tiêu: 0.0861
# Epoch 150, Giá trị hàm mục tiêu: 0.0687
# Epoch 160, Giá trị hàm mục tiêu: 0.0607
# Dừng sớm tại epoch 163, giá trị hàm mục tiêu thay đổi: 0.000055
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  2000  2.008008   7.690863          0.9575  0.959233
# Start preprocessing data
# (2000, 27173)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 13.5300
# Epoch 20, Giá trị hàm mục tiêu: 3.1903
# Epoch 30, Giá trị hàm mục tiêu: 0.5663
# Epoch 40, Giá trị hàm mục tiêu: 0.3984
# Epoch 50, Giá trị hàm mục tiêu: 0.2435
# Epoch 60, Giá trị hàm mục tiêu: 0.1633
# Epoch 70, Giá trị hàm mục tiêu: 0.1392
# Epoch 80, Giá trị hàm mục tiêu: 0.1133
# Epoch 90, Giá trị hàm mục tiêu: 0.1082
# Epoch 100, Giá trị hàm mục tiêu: 0.2481
# Dừng sớm tại epoch 103, giá trị hàm mục tiêu thay đổi: 0.000031
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  2500  1.994745   9.652253           0.972  0.972222
# Start preprocessing data
# (2400, 30652)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 2.5817
# Epoch 20, Giá trị hàm mục tiêu: 0.5433
# Epoch 30, Giá trị hàm mục tiêu: 0.3111
# Epoch 40, Giá trị hàm mục tiêu: 0.2157
# Epoch 50, Giá trị hàm mục tiêu: 0.1804
# Epoch 60, Giá trị hàm mục tiêu: 0.1259
# Epoch 70, Giá trị hàm mục tiêu: 0.1282
# Epoch 80, Giá trị hàm mục tiêu: 0.1049
# Epoch 90, Giá trị hàm mục tiêu: 0.0916
# Epoch 100, Giá trị hàm mục tiêu: 0.0854
# Epoch 110, Giá trị hàm mục tiêu: 0.0773
# Epoch 120, Giá trị hàm mục tiêu: 0.0736
# Epoch 130, Giá trị hàm mục tiêu: 0.1122
# Epoch 140, Giá trị hàm mục tiêu: 0.0653
# Epoch 150, Giá trị hàm mục tiêu: 0.0634
# Epoch 160, Giá trị hàm mục tiêu: 0.0622
# Epoch 170, Giá trị hàm mục tiêu: 0.0581
# Dừng sớm tại epoch 170, giá trị hàm mục tiêu thay đổi: 0.000002
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  3000  4.121941  11.528887        0.966667  0.966887
# Start preprocessing data
# (2800, 34601)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 5.7413
# Epoch 20, Giá trị hàm mục tiêu: 1.5700
# Epoch 30, Giá trị hàm mục tiêu: 0.3305
# Epoch 40, Giá trị hàm mục tiêu: 0.2703
# Epoch 50, Giá trị hàm mục tiêu: 0.5496
# Epoch 60, Giá trị hàm mục tiêu: 0.1625
# Epoch 70, Giá trị hàm mục tiêu: 0.1130
# Epoch 80, Giá trị hàm mục tiêu: 0.0998
# Epoch 90, Giá trị hàm mục tiêu: 0.0901
# Epoch 100, Giá trị hàm mục tiêu: 0.0800
# Epoch 110, Giá trị hàm mục tiêu: 0.0767
# Epoch 120, Giá trị hàm mục tiêu: 0.0774
# Epoch 130, Giá trị hàm mục tiêu: 0.0797
# Dừng sớm tại epoch 137, giá trị hàm mục tiêu thay đổi: 0.000058
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  3500  6.403429  13.534785        0.965714  0.968504
# Start preprocessing data
# (3200, 36844)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 1.5106
# Epoch 20, Giá trị hàm mục tiêu: 0.3836
# Epoch 30, Giá trị hàm mục tiêu: 0.2327
# Epoch 40, Giá trị hàm mục tiêu: 0.2373
# Epoch 50, Giá trị hàm mục tiêu: 0.1568
# Epoch 60, Giá trị hàm mục tiêu: 0.1248
# Epoch 70, Giá trị hàm mục tiêu: 0.1011
# Epoch 80, Giá trị hàm mục tiêu: 0.1033
# Epoch 90, Giá trị hàm mục tiêu: 0.0816
# Dừng sớm tại epoch 91, giá trị hàm mục tiêu thay đổi: 0.000092
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  4000  7.771331  15.552768          0.9625  0.966592
# Start preprocessing data
# (3600, 40208)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 4.2351
# Epoch 20, Giá trị hàm mục tiêu: 0.3781
# Epoch 30, Giá trị hàm mục tiêu: 0.2500
# Epoch 40, Giá trị hàm mục tiêu: 0.1494
# Epoch 50, Giá trị hàm mục tiêu: 0.1663
# Epoch 60, Giá trị hàm mục tiêu: 0.2046
# Epoch 70, Giá trị hàm mục tiêu: 0.0898
# Epoch 80, Giá trị hàm mục tiêu: 0.0844
# Epoch 90, Giá trị hàm mục tiêu: 0.0764
# Dừng sớm tại epoch 99, giá trị hàm mục tiêu thay đổi: 0.000039
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  4500  8.942526  17.628166        0.966667  0.968017
# Start preprocessing data
# (4000, 42051)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 2.1426
# Epoch 20, Giá trị hàm mục tiêu: 0.3572
# Epoch 30, Giá trị hàm mục tiêu: 0.2093
# Dừng sớm tại epoch 30, giá trị hàm mục tiêu thay đổi: 0.000097
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  5000  8.173144  19.582747           0.959  0.960386
# Start preprocessing data
# (4400, 45078)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 1.3986
# Epoch 20, Giá trị hàm mục tiêu: 0.3043
# Epoch 30, Giá trị hàm mục tiêu: 0.2092
# Epoch 40, Giá trị hàm mục tiêu: 0.1450
# Epoch 50, Giá trị hàm mục tiêu: 0.1120
# Epoch 60, Giá trị hàm mục tiêu: 0.0983
# Epoch 70, Giá trị hàm mục tiêu: 0.0861
# Epoch 80, Giá trị hàm mục tiêu: 0.0837
# Epoch 90, Giá trị hàm mục tiêu: 0.0796
# Epoch 100, Giá trị hàm mục tiêu: 0.0772
# Epoch 110, Giá trị hàm mục tiêu: 0.0720
# Epoch 120, Giá trị hàm mục tiêu: 0.0699
# Epoch 130, Giá trị hàm mục tiêu: 0.0670
# Dừng sớm tại epoch 137, giá trị hàm mục tiêu thay đổi: 0.000012
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  5500  13.653205   21.43947        0.963636  0.965636
# Start preprocessing data
# (4800, 45966)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 3.1858
# Epoch 20, Giá trị hàm mục tiêu: 0.2807
# Epoch 30, Giá trị hàm mục tiêu: 0.1919
# Epoch 40, Giá trị hàm mục tiêu: 0.2270
# Epoch 50, Giá trị hàm mục tiêu: 0.1080
# Epoch 60, Giá trị hàm mục tiêu: 0.1053
# Epoch 70, Giá trị hàm mục tiêu: 0.0869
# Epoch 80, Giá trị hàm mục tiêu: 0.1146
# Epoch 90, Giá trị hàm mục tiêu: 0.0807
# Epoch 100, Giá trị hàm mục tiêu: 0.0756
# Epoch 110, Giá trị hàm mục tiêu: 0.0872
# Epoch 120, Giá trị hàm mục tiêu: 0.0736
# Epoch 130, Giá trị hàm mục tiêu: 0.0943
# Epoch 140, Giá trị hàm mục tiêu: 0.0687
# Dừng sớm tại epoch 147, giá trị hàm mục tiêu thay đổi: 0.000027
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  6000  14.563398   23.29878        0.975833  0.977147
# Start preprocessing data
# (5200, 48115)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 1.2303
# Epoch 20, Giá trị hàm mục tiêu: 0.2647
# Epoch 30, Giá trị hàm mục tiêu: 0.1581
# Epoch 40, Giá trị hàm mục tiêu: 0.1245
# Epoch 50, Giá trị hàm mục tiêu: 0.1069
# Epoch 60, Giá trị hàm mục tiêu: 0.0957
# Epoch 70, Giá trị hàm mục tiêu: 0.0880
# Epoch 80, Giá trị hàm mục tiêu: 0.0868
# Epoch 90, Giá trị hàm mục tiêu: 0.0813
# Epoch 100, Giá trị hàm mục tiêu: 0.0760
# Epoch 110, Giá trị hàm mục tiêu: 0.0748
# Epoch 120, Giá trị hàm mục tiêu: 0.0727
# Dừng sớm tại epoch 126, giá trị hàm mục tiêu thay đổi: 0.000063
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  6500  15.397516  25.154284        0.973077  0.974508
# Start preprocessing data
# (5600, 51237)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 1.4403
# Epoch 20, Giá trị hàm mục tiêu: 0.2528
# Epoch 30, Giá trị hàm mục tiêu: 0.1712
# Epoch 40, Giá trị hàm mục tiêu: 0.1814
# Epoch 50, Giá trị hàm mục tiêu: 0.1313
# Epoch 60, Giá trị hàm mục tiêu: 0.1060
# Epoch 70, Giá trị hàm mục tiêu: 0.1139
# Epoch 80, Giá trị hàm mục tiêu: 0.0876
# Epoch 90, Giá trị hàm mục tiêu: 0.0787
# Epoch 100, Giá trị hàm mục tiêu: 0.0764
# Epoch 110, Giá trị hàm mục tiêu: 0.1295
# Epoch 120, Giá trị hàm mục tiêu: 0.0806
# Dừng sớm tại epoch 129, giá trị hàm mục tiêu thay đổi: 0.000097
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  7000  14.781868  26.989283        0.977143  0.978466
# Start preprocessing data
# (6000, 52784)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 0.5039
# Epoch 20, Giá trị hàm mục tiêu: 0.2418
# Epoch 30, Giá trị hàm mục tiêu: 0.1434
# Epoch 40, Giá trị hàm mục tiêu: 0.1217
# Epoch 50, Giá trị hàm mục tiêu: 0.1097
# Epoch 60, Giá trị hàm mục tiêu: 0.1057
# Epoch 70, Giá trị hàm mục tiêu: 0.0861
# Dừng sớm tại epoch 76, giá trị hàm mục tiêu thay đổi: 0.000095
#   class_name     n      time  prep_time  accuracy_score  f1_score
# 0        SVM  7500  14.59569  29.212253        0.974667  0.975484
# Start preprocessing data
# (6400, 56225)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 0.5573
# Epoch 20, Giá trị hàm mục tiêu: 0.2768
# Epoch 30, Giá trị hàm mục tiêu: 0.2050
# Epoch 40, Giá trị hàm mục tiêu: 0.1178
# Epoch 50, Giá trị hàm mục tiêu: 0.1037
# Epoch 60, Giá trị hàm mục tiêu: 0.1577
# Epoch 70, Giá trị hàm mục tiêu: 0.0885
# Epoch 80, Giá trị hàm mục tiêu: 0.0823
# Epoch 90, Giá trị hàm mục tiêu: 0.0898
# Epoch 100, Giá trị hàm mục tiêu: 0.0782
# Dừng sớm tại epoch 106, giá trị hàm mục tiêu thay đổi: 0.000095
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  8000  18.731439  30.904573          0.9775  0.978313
# Start preprocessing data
# (6800, 58721)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 0.4726
# Epoch 20, Giá trị hàm mục tiêu: 0.1949
# Epoch 30, Giá trị hàm mục tiêu: 0.1315
# Epoch 40, Giá trị hàm mục tiêu: 0.1158
# Epoch 50, Giá trị hàm mục tiêu: 0.1022
# Epoch 60, Giá trị hàm mục tiêu: 0.0911
# Epoch 70, Giá trị hàm mục tiêu: 0.0854
# Epoch 80, Giá trị hàm mục tiêu: 0.0835
# Epoch 90, Giá trị hàm mục tiêu: 0.0826
# Epoch 100, Giá trị hàm mục tiêu: 0.0803
# Dừng sớm tại epoch 107, giá trị hàm mục tiêu thay đổi: 0.000002
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  8500  19.038033  33.161819        0.974118  0.975141
# Start preprocessing data
# (7200, 60594)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 0.5622
# Epoch 20, Giá trị hàm mục tiêu: 0.1871
# Epoch 30, Giá trị hàm mục tiêu: 0.1487
# Epoch 40, Giá trị hàm mục tiêu: 0.1163
# Epoch 50, Giá trị hàm mục tiêu: 0.1082
# Epoch 60, Giá trị hàm mục tiêu: 0.1338
# Epoch 70, Giá trị hàm mục tiêu: 0.0973
# Epoch 80, Giá trị hàm mục tiêu: 0.0836
# Dừng sớm tại epoch 87, giá trị hàm mục tiêu thay đổi: 0.000093
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  9000  20.527917  34.559794        0.979444  0.980161
# Start preprocessing data
# (7600, 62190)
# End preprocessing data
# Epoch 10, Giá trị hàm mục tiêu: 0.4344
# Epoch 20, Giá trị hàm mục tiêu: 0.1788
# Epoch 30, Giá trị hàm mục tiêu: 0.1259
# Epoch 40, Giá trị hàm mục tiêu: 0.1062
# Epoch 50, Giá trị hàm mục tiêu: 0.0960
# Epoch 60, Giá trị hàm mục tiêu: 0.0923
# Epoch 70, Giá trị hàm mục tiêu: 0.0881
# Epoch 80, Giá trị hàm mục tiêu: 0.0862
# Epoch 90, Giá trị hàm mục tiêu: 0.0810
# Epoch 100, Giá trị hàm mục tiêu: 0.0802
# Epoch 110, Giá trị hàm mục tiêu: 0.0820
# Dừng sớm tại epoch 113, giá trị hàm mục tiêu thay đổi: 0.000031
#   class_name     n       time  prep_time  accuracy_score  f1_score
# 0        SVM  9500  23.870706  36.679264            0.98  0.980943
